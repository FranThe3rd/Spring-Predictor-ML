# %%
import pandas as pd #type: ignore

# %%
data = pd.read_csv('soil.csv', parse_dates=['day'])

dat = data.copy()
dat['year'] = dat.day.dt.year
dat['day_of_year'] = dat.day.dt.day_of_year
# holder = dat['day']
dat = dat.drop(columns=['day']).pivot(index='year', columns='day_of_year')
dat.columns = ["_".join(str(x) for x in a) for a in dat.columns.to_flat_index()]
# dat['day_of_year'] = holder.dt.day_of_year

dat.head()
# Out:
#       mean_soil_temp_1  mean_soil_temp_2  mean_soil_temp_3  mean_soil_temp_4  \
# year
# 1947            -3.220         -2.533333         -1.733333          0.729167
# 1948             0.724          0.725000          0.575000          0.220833
# 1949             0.080          0.112500          0.091667          0.245833
# 1950             2.276          5.641667          8.170833         11.758333
# 1951             3.632          3.770833          3.991667          3.945833
#
#       mean_soil_temp_5  mean_soil_temp_6  mean_soil_temp_7  mean_soil_temp_8  \
# year
# 1947          0.162500         -0.458333         -1.475000          0.750000
# 1948          0.333333          0.466667          0.395833          0.262500
# 1949          0.570833          0.912500          2.545833          3.750000
# 1950          7.291667          7.058333          3.087500          0.566667
# 1951          3.237500          3.250000          3.141667          2.712500
#
#       mean_soil_temp_9  mean_soil_temp_10  ...  max_soil_moisture_47  \
# year                                       ...
# 1947          0.325000          -1.387500  ...                 0.492
# 1948          0.383333           0.320833  ...                 0.515
# 1949          4.875000           3.391667  ...                 0.503
# 1950          0.475000           5.708333  ...                 0.501
# 1951          2.133333           2.350000  ...                 0.484
#
#       max_soil_moisture_48  max_soil_moisture_49  max_soil_moisture_50  \
# year
# 1947                 0.475                 0.474                 0.469
# 1948                 0.517                 0.518                 0.519
# 1949                 0.486                 0.477                 0.469
# 1950                 0.484                 0.476                 0.474
# 1951                 0.512                 0.505                 0.519
#
#       max_soil_moisture_51  max_soil_moisture_52  max_soil_moisture_53  \
# year
# 1947                 0.466                 0.465                 0.464
# 1948                 0.516                 0.488                 0.482
# 1949                 0.517                 0.491                 0.515
# 1950                 0.469                 0.466                 0.518
# 1951                 0.506                 0.519                 0.493
#
#       max_soil_moisture_54  max_soil_moisture_55  max_soil_moisture_56
# year
# 1947                 0.462                 0.460                 0.458
# 1948                 0.476                 0.473                 0.506
# 1949                 0.501                 0.485                 0.511
# 1950                 0.495                 0.480                 0.478
# 1951                 0.477                 0.469                 0.463
#
# [5 rows x 336 columns]
